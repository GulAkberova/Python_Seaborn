# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
num= np.random.randn(150)

# %%
sns.distplot(num)
# Out:
# C:\Users\Gul\AppData\Local\Temp\ipykernel_8708\702644673.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(num)
# <Axes: ylabel='Density'>

# %%
sns.distplot(num, color='red')
# Out:
# C:\Users\Gul\AppData\Local\Temp\ipykernel_8708\3599940637.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(num, color='red')
# <Axes: ylabel='Density'>

# %%
label_dist= pd.Series(num, name='variable x')

# %%
sns.distplot(label_dist)
# Out:
# C:\Users\Gul\AppData\Local\Temp\ipykernel_8708\2491584116.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist)
# <Axes: xlabel='variable x', ylabel='Density'>

# %%
sns.distplot(label_dist,vertical=True)
# Out:
# C:\Users\Gul\AppData\Local\Temp\ipykernel_8708\4200876424.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist,vertical=True)
# <Axes: xlabel='Density', ylabel='variable x'>

# %%
sns.distplot(label_dist,vertical=True, color='red')
# Out:
# C:\Users\Gul\AppData\Local\Temp\ipykernel_8708\3575863090.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist,vertical=True, color='red')
# <Axes: xlabel='Density', ylabel='variable x'>

# %%
sns.distplot(label_dist,hist=False)
# Out:
# C:\Users\Gul\AppData\Local\Temp\ipykernel_8708\1705238885.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist,hist=False)
# <Axes: xlabel='variable x', ylabel='Density'>

# %%
sns.distplot(label_dist, rug=True,hist=False)
# Out:
# C:\Users\Gul\AppData\Local\Temp\ipykernel_8708\1766073086.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist, rug=True,hist=False)
# <Axes: xlabel='variable x', ylabel='Density'>

# %%
sns.distplot(label_dist,hist=False, rug=True, color='green')
# Out:
# C:\Users\Gul\AppData\Local\Temp\ipykernel_8708\2722094439.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_dist,hist=False, rug=True, color='green')
# <Axes: xlabel='variable x', ylabel='Density'>
